# %%
from matplotlib import pyplot as plt

# %%
metric_sparsity_old = [0.91666667, 0.66666667, 0.91666667, 0.75,0.83333333,0.83333333,0.58333333,0.83333333,0.75,0.83333333]
metric_sparsity_new = [0.5,0.41666667,0.33333333,0.41666667,0.5,0.5,0.41666667,0.5,0.5 ,0.58333333]

# %%
# Calculate the difference between the two metrics
difference = [m1 - m2 for m1, m2 in zip(metric_sparsity_old, metric_sparsity_new)]

# Visualize the results
x = list(range(len(metric_sparsity_old)))

plt.scatter(x, metric_sparsity_old, label="Original method")
plt.scatter(x, metric_sparsity_new, label="New method")
# plt.scatter(x, difference, label="Difference", linestyle="--")

plt.xlabel("Index")
plt.ylabel("Value")
plt.title("Metric: Sparsity")
plt.legend()

plt.show()

# %%
metric_change_old = [331.23804039,331.823247,3602.2351798,598.93153733,331.76807385,
 2153.06045474,2292.00609821,330.52983959,332.46291576,1982.93142308,
 1065.42965849,331.89754118,331.46202259,895.74045308,331.44430094,
  331.06966796,331.50455736,853.25609102,332.5939003,1049.85153174]

# %%
metric_change_new = [356.07710392,4493.33087035,1423.37074961,627.31908826,1015.97172643,
 2153.03514178,2354.31008031,848.98825389,5878.25263763,1531.52130534,
 6329.18184318,6256.63771899,2153.0468254,1004.00171017,1037.69302363,
  864.49356564,5299.77750248,548.29315859,5199.75254224,2559.16031757]

# %%
# do same as above
difference = [m1 - m2 for m1, m2 in zip(metric_change_old, metric_change_new)]

x = list(range(len(metric_change_old)))

plt.scatter(x, metric_change_old, label="Original method")
plt.scatter(x, metric_change_new, label="New method")
# plt.scatter(x, difference, label="Difference", linestyle="--")

plt.xlabel("Index")
plt.ylabel("Value")
plt.title("Metric: Change")
plt.legend()

plt.show()

# %%
metric_change_weight_old = [217.23867676,518.87902026,6794.49574964,842.24778427,528.4292627,
 1259.0545261,1753.54345116,147.40462199,637.80512655,2125.8868563,
  813.84386578,114.34494222,143.6317169,996.50861387,363.370123,
  357.03699175,188.88710701,812.86882389,234.67412719,1458.32380071]

# %%
metric_change_weight_new = [223.10456794,3837.9625812,2494.79793663,786.38911431,2036.65141119,
 1258.931398,1913.78695706,364.46663327,3840.80688799,1639.32821332,
 4830.96259085,2265.25335332,1509.43676999,1140.85137205,905.95575672,
 931.41080449,2298.46273099,772.55505221,4135.6977975,2661.98704237]

# %%
# do same as above
difference = [m1 - m2 for m1, m2 in zip(metric_change_weight_old, metric_change_weight_new)]

x = list(range(len(metric_change_weight_old)))

plt.scatter(x, metric_change_weight_old, label="Original method")
plt.scatter(x, metric_change_weight_new, label="New method")
# plt.scatter(x, difference, label="Difference", linestyle="--")

plt.xlabel("Index")
plt.ylabel("Value")
plt.title("Metric: Change Weight")
plt.legend()

plt.show()

# %%
metric_closeness_old =

# %%
metric_closeness_new = [0.23320136,0.06596095,0.20849662,0.09675799,0.00947134,0.05930113,
 0.0429397,0.29767283,0.00471159,0.10550637,0.02214366,0.23976845,
 0.15719722,0.21830205,0.03412155,0.20121773,0.00266918,0.05773467
]

# %%
import numpy as np
# print mean and std for both metrics
print("Mean and std of metric sparsity old: ", np.mean(metric_sparsity_old), np.std(metric_sparsity_old))
print("Mean and std of metric sparsity new: ", np.mean(metric_sparsity_new), np.std(metric_sparsity_new))
print()
print("Mean and std of metric change old: ", np.mean(metric_change_old), np.std(metric_change_old))
print("Mean and std of metric change new: ", np.mean(metric_change_new), np.std(metric_change_new))
print()
print("Mean and std of metric change weight old: ", np.mean(metric_change_weight_old), np.std(metric_change_weight_old))
print("Mean and std of metric change weight new: ", np.mean(metric_change_weight_new), np.std(metric_change_weight_new))
# Out:
# Mean and std of metric sparsity old:  0.791666666 0.10034662204357238
# Mean and std of metric sparsity new:  0.46666666700000003 0.06666666600000004
#
# Mean and std of metric change old:  907.0618267205 885.3805493821375
# Mean and std of metric change new:  2596.7107582705 2065.862511283847
#
# Mean and std of metric change weight old:  1015.4237594024999 1436.7213751498682
# Mean and std of metric change weight new:  1992.4399485699996 1284.5432110205973
